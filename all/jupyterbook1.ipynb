# %%
import numpy as np
a=np.array([1,2,3,4,5])
a.reshape(5,1)
a=(a>3)
a
# Out:
# array([False, False, False,  True,  True])

# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\memon\\Documents\\python\\survey.csv')
df["Year"].mean()
df['Year'].max()
df
df.head(3)
df.tail(2)
df.columns
df.Year
df[["Year","Units"]][df["Year"]==2013]
df.describe()
dfy=df.set_index("Year")
dfy["Value"][df["Year"]==2018]
df
df["Year"][1:6]
import matplotlib.pyplot as pypt
# %matplotlib inline
x=[1,2,3,4,5,6,7]
y=[34,54,12,32,15,56,32]
pypt.plot(x,y)
